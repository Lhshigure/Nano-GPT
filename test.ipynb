# %%
import torch

# 1. 查看 PyTorch 版本
print(f"PyTorch 版本: {torch.__version__}")

# 2. 查看 PyTorch 编译时使用的 CUDA 版本
print(f"PyTorch 内部 CUDA 版本: {torch.version.cuda}")

# 3. 查看 cuDNN 版本
print(f"cuDNN 版本: {torch.backends.cudnn.version()}")

# 4. 确认 CUDA 是否可用（最关键的一步）
print(f"CUDA 是否可用: {torch.cuda.is_available()}")

# 5. 查看显卡名称
if torch.cuda.is_available():
    print(f"当前显卡: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch 版本: 2.10.0+cu126
# PyTorch 内部 CUDA 版本: 12.6
# cuDNN 版本: 91002
# CUDA 是否可用: True
# 当前显卡: NVIDIA GeForce RTX 4080 Laptop GPU
